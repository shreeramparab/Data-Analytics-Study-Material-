# %%
from pyspark import SparkContext
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pyspark import SparkContext
#
# File c:\Users\shreeram\Jbooks\myspace\Lib\site-packages\pyspark\__init__.py:71
#      69 from pyspark.util import InheritableThread, inheritable_thread_target
#      70 from pyspark.storagelevel import StorageLevel
# ---> 71 from pyspark.accumulators import Accumulator, AccumulatorParam
#      72 from pyspark.serializers import MarshalSerializer, CPickleSerializer
#      73 from pyspark.taskcontext import TaskContext, BarrierTaskContext, BarrierTaskInfo
#
# File c:\Users\shreeram\Jbooks\myspace\Lib\site-packages\pyspark\accumulators.py:324
#     320         super().shutdown()
#     321         self.server_close()
# --> 324 class AccumulatorUnixServer(socketserver.UnixStreamServer):
#     325     server_shutdown = False
#     327     def __init__(
# ...
