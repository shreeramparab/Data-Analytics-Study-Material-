# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('names.csv',header=0,index_col=0)
print(df)
col = list(df.columns)
df.insert(col.index('salary')+1,'bonus',(df['salary']*0.1).astype(int))
print(df)
df.to_csv('names1.csv',index=True,header=True)
col = list(df.columns)

# %%
df = pd.read_csv('employee.csv',header=0,index_col=0)
print(df)
col = list(df.columns)
df.loc[df['name']=='Shree','gender'] = 'Male'
df.update(df)
print(df)
df.insert(col.index('salary')+1,'bonus',df['salary']*0.1)
print(df)
df.to_csv('employee.csv',index=True,header=True)

# %%
df = pd.read_csv('employee.csv',header=0,index_col=0)
new_df = pd.DataFrame([{'name':'Shreeram','age':27,'gender':'Male','salary':11237,'bonus':1123}],index=[len(df)+1])
df = pd.concat([df,new_df])
print(df)
df.to_csv('employee.csv',index=True,header=True)

# %%
load = 2
df = pd.read_csv('employee.csv',header=0,index_col=0,chunksize=load)
for i in df:
    i['salary'] = i['salary'] * 1.10 - 100
    print(i)
    i.to_csv('employee3.csv',mode='a',index=True,header=False)
# Out:
#      name  age gender   salary   bonus
# id
# 1   Shree   28   Male  13100.0  1200.0
# 2     Ram   29   Male  13100.0  1200.0
#       name  age  gender   salary   bonus
# id
# 3     Riya   45  Female  14200.0  1300.0
# 4   Sushma   15  Female  12000.0  1100.0
#         name  age gender   salary   bonus
# id
# 5       John   22   Male  13100.0  1200.0
# 6   Shreeram   27   Male  12260.7  1123.0

# %%
df = pd.read_csv('employee3.csv',header=None,names=['id','name','age','gender','salary','bonus'],index_col=0)
df.reset_index(inplace=True,drop=True)
df['salary'] = df['salary'].astype(int)
df['id'] = range(1,len(df)+1)  
print(df)
df.set_index('id',inplace=True)
print(df)
df.to_csv('employee3.csv',index=True,header=True)
# Out:
#        name  age gender  salary   bonus  id
# 0      John   22   Male   13100  1200.0   1
# 1  Shreeram   27   Male   12260  1123.0   2
#         name  age gender  salary   bonus
# id
# 1       John   22   Male   13100  1200.0
# 2   Shreeram   27   Male   12260  1123.0

# %%
df = pd.read_csv('employee.csv',usecols=['id','name','age'],index_col=0)
print(df)
# Out:
#         name  age
# id
# 1      Shree   28
# 2        Ram   29
# 3       Riya   45
# 4     Sushma   15
# 5       John   22
# 6   Shreeram   27

# %%
df = pd.read_csv("employee3.csv",index_col=0,header=0)
print(df)
print(df.isnull().sum())
# Out:
#         name   age  gender  salary   bonus
# id
# 1       Riya  25.0  Female   12000  1000.0
# 2       John  22.0    Male   13100  1200.0
# 3   Shreeram  27.0    Male   12260  1123.0
# 4      Shree  24.0    Male   12000  1000.0
# 5        Ram   NaN    Male   12000  1000.0
# name      0
# age       1
# gender    0
# salary    0
# bonus     0
# dtype: int64

# %%
df = pd.read_csv('employee3.csv',header=0,index_col=0)
df = df[df['age']!=25]
# Out:
#         name   age  gender  salary   bonus
# id
# 1       Riya  25.0  Female   12000  1000.0
# 2       John  22.0    Male   13100  1200.0
# 3   Shreeram  27.0    Male   12260  1123.0
# 4      Shree  24.0    Male   12000  1000.0
# 5        Ram   NaN    Male   12000  1000.0
#         name   age gender  salary   bonus
# id
# 2       John  22.0   Male   13100  1200.0
# 3   Shreeram  27.0   Male   12260  1123.0
# 4      Shree  24.0   Male   12000  1000.0
# 5        Ram   NaN   Male   12000  1000.0
#         name   age  gender  salary   bonus
# id
# 1       Riya  25.0  Female   12000  1000.0
# 2       John  22.0    Male   13100  1200.0
# 3   Shreeram  27.0    Male   12260  1123.0
# 4      Shree  24.0    Male   12000  1000.0
# 5        Ram   NaN    Male   12000  1000.0

# %%
df.loc[df['age']==25,'salary'] = None
print(df)
df.isnull().sum()
print(df)
# Out:
#         name   age  gender   salary   bonus
# id
# 1       Riya  25.0  Female     None  1000.0
# 2       John  22.0    Male  13100.0  1200.0
# 3   Shreeram  27.0    Male  12260.0  1123.0
# 4      Shree  24.0    Male    12000  1000.0
# 5        Ram   NaN    Male    12000  1000.0
#         name   age  gender   salary   bonus
# id
# 1       Riya  25.0  Female     None  1000.0
# 2       John  22.0    Male  13100.0  1200.0
# 3   Shreeram  27.0    Male  12260.0  1123.0
# 4      Shree  24.0    Male    12000  1000.0
# 5        Ram   NaN    Male    12000  1000.0

# %%
df['salary'] = df['salary'].fillna(df['bonus'].sum()*10)
print(df)
'''df.loc[df['salary']==12000,'salary'] = None
print(df)'''
# Out:
#         name   age  gender   salary   bonus
# id
# 1       Riya  25.0  Female  53230.0  1000.0
# 2       John  22.0    Male  13100.0  1200.0
# 3   Shreeram  27.0    Male  12260.0  1123.0
# 4      Shree  24.0    Male  53230.0  1000.0
# 5        Ram   NaN    Male  53230.0  1000.0
# "df.loc[df['salary']==12000,'salary'] = None\nprint(df)"

# %%
df['salary'] = df['salary'].replace(to_replace=df['bonus'].sum()*5, value=np.nan)

# %%
df.fillna(method="ffill", inplace=True)
df.fillna(method="bfill", inplace=True)
df.dropna(inplace=True)
df.loc[df["Salary"].notnull(), "Bonus"] = df["Salary"] * 0.10
