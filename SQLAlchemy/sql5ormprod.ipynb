# %% [markdown]
# joinedload() (avoid N+1 queries)
#
# load_only() (massive speed improvement)
#
# aliased()
#
# cte() (advanced SQL)
#
# window functions

# %%
from sqlalchemy import create_engine , Column , Integer , String , text , select , func , desc , Table , join , outerjoin , exists , update , delete , inspect 
from sqlalchemy.orm import sessionmaker , declarative_base ,  joinedload

# %%
customer_data = (
    
        [1,  "Alice Johnson",  "Laptop",              "Delivered"],
        [2,  "Bob Smith",      "Headphones",          "In Transit"],
        [3,  "Carol White",    "Smartphone",          "Pending"],
        [4,  "David Brown",    "Keyboard",            "Delivered"],
        [5,  "Eva Martinez",   "Monitor",             "In Transit"],
        [6,  "Frank Wilson",   "Mouse",               "Delivered"],
        [7,  "Grace Lee",      "Webcam",              "Cancelled"],
        [8,  "Henry Taylor",   "USB",                 "Pending"],
        [9,  "Isla Anderson",  "Chair",               "Pending"],
        [10, "Jack Thomas",    "Keyboard",            "Delivered"],
    
)
# Out:
#              name     product      status
# id
# 1   Alice Johnson      Laptop   Delivered
# 2       Bob Smith  Headphones  In Transit
# 3     Carol White  Smartphone     Pending
# 4     David Brown    Keyboard   Delivered
# 5    Eva Martinez     Monitor  In Transit
# 6    Frank Wilson       Mouse   Delivered
# 7       Grace Lee      Webcam   Cancelled
# 8    Henry Taylor         USB     Pending
# 9   Isla Anderson       Chair     Pending
# 10    Jack Thomas    Keyboard   Delivered

# %%
engine  = create_engine("mysql+pymysql://root:1234@localhost/sqlalchemy")
Base = declarative_base()
Session = sessionmaker(engine)

# %%
Base.metadata.clear()
class People (Base):
    __tablename__='people'
    __table_args__ = {'extend_existing':True}
    id = Column(Integer, primary_key=True)
    name = Column(String(50))
    product = Column(String(20))
    def __repr__(self):
        return f"{self.id:<3} {self.name:<20} {self.product:<20}"
    
Base.metadata.create_all(engine)
# Out:
# C:\Users\devgu\AppData\Local\Temp\ipykernel_11764\2815864588.py:2: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.People, and will be replaced in the string-lookup table.
#   class People (Base):

# %%
People.__table__.columns.keys()
# Out:
# ['id', 'name', 'product']

# %%
row = [People(id=a,name=b,product=c)   for a,b,c,*_ in customer_data]
with Session() as session:
    with session.begin():
        session.add_all(row)

# %%
with Session() as  session:
    with session.begin():
        stmt = select(People)
        result = session.execute(stmt).scalars().all()
        for row in result :
            print(row)
# Out:
# 1   Alice Johnson        Laptop
# 2   Bob Smith            Headphones
# 3   Carol White          Smartphone
# 4   David Brown          Keyboard
# 5   Eva Martinez         Monitor
# 6   Frank Wilson         Mouse
# 7   Grace Lee            Webcam
# 8   Henry Taylor         USB
# 9   Isla Anderson        Chair
# 10  Jack Thomas          Keyboard
