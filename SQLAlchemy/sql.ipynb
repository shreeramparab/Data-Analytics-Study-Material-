# %%
from sqlalchemy import create_engine,text

# %%
engine = create_engine('sqlite:///mydatabase.db',echo=True)

# %%
conn =engine.connect()

# %%
conn.execute(text("create table if not exists users (id integer primary key autoincrement, name text, email text)"))
conn.commit()
# Out:
# 2026-02-16 19:47:39,269 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-02-16 19:47:39,275 INFO sqlalchemy.engine.Engine create table if not exists users (id integer primary key autoincrement, name text, email text)
# 2026-02-16 19:47:39,278 INFO sqlalchemy.engine.Engine [generated in 0.00939s] ()
# 2026-02-16 19:47:39,281 INFO sqlalchemy.engine.Engine COMMIT

# %%
engine = create_engine("+pymysql://test:1234/localhost:3306/okay",echo=True)
# Out:
# ---------------------------------------------------------------------------
# NoSuchModuleError                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 engine = create_engine("+pymysql://test:1234/localhost:3306/okay",echo=True)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File c:\Users\shreeram\vscode\Jbooks\Jbookspace\Lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File c:\Users\shreeram\vscode\Jbooks\Jbookspace\Lib\site-packages\sqlalchemy\engine\create.py:568, in create_engine(url, **kwargs)
#     564 u = _url.make_url(url)
# ...
