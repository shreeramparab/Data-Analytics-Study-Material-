# %%
import pandas as pd 
import numpy as np
import time

# %%
for x in range(10) :
    for y in range(10):
        data =
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 for x in range(10) :
#       2     for y in range(10):
# ----> 3         data = data + np.random.rand(150,200)
#
# TypeError: unsupported operand type(s) for +: 'type' and 'float'
